# %%
def display_menu():
    print("\n welcome to data analyzer and transformer program")
    print("\n main menu")
    print("1.Input data")
    print("2. Display Data summary(Built-in-functions)")
    print("3.Calculate Factorial (Recurison)")
    print("4.Filter Data by Threshold(Lambda Function)")
    print("5.Sort Data")
    print("6.Display Dataset Statistics(Return Multiple Values)")
    print("7.Exit Program")

def input_data():
    data = list(map(int,input("\n Enter data for a 1D array(seperated by space):"). split()))
    print("Data has been stored successfully !")
    return data 

def data_summary(data):
    print("data summary:")
    print(" Total element:", len(data))
    print("Minimum Value:", min(data))
    print("Mximum Value:", max(data))
    print("sum of all value:", sum(data))

def factorial(n):
    def factorial(n):
        if n == 0 or n == 1:
            return 1
        else:
            return n * factorial(n -1)
        
def filter_data(data):
    threshold = int(input("Enter threshold value: "))
    filtered = list(filter(lambda x: x > threshold, data))
    print("Filtered data (values greater than threshold):", filtered)

def sort_data(data):
    print("\n1. Sort in Ascending Order")
    print("2. Sort in Descending Order")
    choice = input("Enter your choice (1- or 2): ")

def dataset_statistics():
    if not dataset_statistics:
        print("Please enter data first using option 1.")
        return
    if isinstance(dataset_statistics[0],list):
        print("Statistics works only for 1d data.")
        return
    total = sum(dataset_statistics)
    average = total / len(dataset_statistics)
    return min(dataset_statistics), max(dataset_statistics), total,average 

def show_statistics():
    stats = dataset_statistics()
    if stats:
        print("\nDataset Statistics")
        print("Minimum Value:", stats[0])
        print("Maximum value:", stats[1])
        print("Total sum:",stats[2])
        print("Average:", round(stats[3],2))

def exit_program():
    print("Thank you for using the data analyzer and tranformer program .goodbye!")
    exit()


    
data = []
while True:
    display_menu()
    choice = input("\n please enter your choice (1-7):") 

    match choice:
      case '1':
        data = input_data()
        if data:
            print("All data is perfect!")
            print("Your data:",data)
        else:
            print("Invalid data! please try again.")
    
      case '2':
        if data:
            print("Displaying Data Summary")
            print("Data summary displayed successfully!")
        else:
            print("No data found")

      case '3':
        n = int(input("Enter number to calculate factorial:"))
        if n < 0 :
            print("Factorial does not exist for negative numbers.")
        else :
            print(f" factorial of {n} is : {factorial(n)}")

      case '4':
        if filter:
            print(f" Filter data value >{threshold}: {filter}")
        else:
            print(f"No value is greater than{threshold} were found.") 

      case'5':
        if choice =='1':
           sorted_data = sorted(data)
           print(f"Data sorted in ascending order :{sorted_data}")
        elif choice == '2':
            sorted_data = sorted(data,reverse=True)
        print(f"Data sorted in descending order:{sorted_data}")
        # else:
        #     print("invalid sort choice")
      case '6':
            if data:
                show_statistics(data)
            else:
                print("No data found! Please input data first.")
      case '7':
            exit_program()

      case _:
            print("Invalid choice! Please enter a number between 1 and 7.")
